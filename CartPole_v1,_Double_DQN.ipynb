# %% [markdown]
# # Import libraries

# %%
import random
import collections
import numpy as np

import imageio

import torch
import torch.nn as nn
import torch.optim as optim
import gymnasium as gym

# %% [markdown]
# # Hyperparameters

# %%
ENV_NAME = "CartPole-v1"

GAMMA = 0.99
LR = 1e-3

BATCH_SIZE = 64
BUFFER_CAPACITY = 50_000
WARMUP_STEPS = 1000          # cần đủ mẫu trong buffer trước khi train
TRAIN_EVERY = 4              # mỗi 4 step môi trường thì train 1 lần

TARGET_UPDATE_EVERY = 1000   # mỗi 1000 bước update mạng target

EPS_START = 1.0
EPS_END = 0.05
EPS_DECAY = 0.995

MAX_EPISODES = 5000

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Replay Buffer

# %%
Transition = collections.namedtuple("Transition", ["state", "action", "reward", "next_state", "done"])


class ReplayBuffer:
    def __init__(self, capacity: int):
        self.buffer = collections.deque(maxlen=capacity)

    def push(self, state, action, reward, next_state, done):
        self.buffer.append(Transition(state, action, reward, next_state, done))

    def sample(self, batch_size: int):
        batch = random.sample(self.buffer, batch_size)
        states      = torch.tensor(np.array([t.state      for t in batch]), dtype=torch.float32)
        actions     = torch.tensor([t.action for t in batch], dtype=torch.int64).unsqueeze(-1)
        rewards     = torch.tensor([t.reward for t in batch], dtype=torch.float32).unsqueeze(-1)
        next_states = torch.tensor(np.array([t.next_state for t in batch]), dtype=torch.float32)
        dones       = torch.tensor([t.done   for t in batch], dtype=torch.float32).unsqueeze(-1)
        return states, actions, rewards, next_states, dones

    def __len__(self):
        return len(self.buffer)

# %% [markdown]
# # Q-Network

# %%
class QNetwork(nn.Module):
    def __init__(self, obs_dim: int, n_actions: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions),
        )

    def forward(self, x):
        return self.net(x)

# %% [markdown]
# # ε-greedy

# %%
def select_action(q_net: QNetwork, state: np.ndarray, eps: float, env: gym.Env):
    # random với xác suất eps
    if random.random() < eps:
        return env.action_space.sample()
    # còn lại chọn argmax Q(s,a)
    state_t = torch.tensor(state, dtype=torch.float32, device=DEVICE).unsqueeze(0)  # [1, obs_dim]
    with torch.no_grad():
        q_values = q_net(state_t)  # [1, n_actions]
        action = int(torch.argmax(q_values, dim=1).item())
    return action

# %% [markdown]
# # Training DQN

# %%
def train_step(q_online, q_target, optimizer, replay_buffer):
    if len(replay_buffer) < BATCH_SIZE:
        return None  # chưa đủ batch

    states, actions, rewards, next_states, dones = replay_buffer.sample(BATCH_SIZE)
    states = states.to(DEVICE)
    actions = actions.to(DEVICE)
    rewards = rewards.to(DEVICE)
    next_states = next_states.to(DEVICE)
    dones = dones.to(DEVICE)

    # Q(s,a) từ mạng ONLINE
    q_values = q_online(states)              # [B, n_actions]
    q_sa = q_values.gather(1, actions)       # [B, 1]

    # ====== DOUBLE DQN: TÍNH TARGET ======
    with torch.no_grad():
        # 1) ONLINE chọn action tốt nhất ở state s'
        q_next_online = q_online(next_states)              # [B, n_actions]
        best_next_actions = torch.argmax(q_next_online, dim=1, keepdim=True)  # [B, 1]

        # 2) TARGET đánh giá Q(s', a*) với a* do ONLINE chọn
        q_next_target = q_target(next_states)              # [B, n_actions]
        q_next_best = q_next_target.gather(1, best_next_actions)  # [B, 1]

        # 3) Bellman target
        y = rewards + GAMMA * (1.0 - dones) * q_next_best  # [B, 1]

    loss = nn.MSELoss()(q_sa, y)

    optimizer.zero_grad()
    loss.backward()
    nn.utils.clip_grad_norm_(q_online.parameters(), 10.0)
    optimizer.step()

    return loss.item()

# %% [markdown]
# # Helper

# %%
def record_policy(env, q_online, eps=0.0, filename="cartpole_demo.mp4"):
    frames = []
    reset_out = env.reset()
    if isinstance(reset_out, tuple):
        state, _ = reset_out
    else:
        state = reset_out

    done = False
    while not done:
        frame = env.render()  # lấy frame
        frames.append(frame)

        # chọn action greedy
        action = select_action(q_online, state, eps, env)
        step_out = env.step(action)
        if len(step_out) == 5:
            next_state, reward, terminated, truncated, _ = step_out
            done = terminated or truncated
        else:
            next_state, reward, done, _ = step_out
        state = next_state

    env.close()
    imageio.mimsave(filename, frames, fps=30)
    print(f"✅ Video saved: {filename}")

# %% [markdown]
# # Main loop

# %%
def main():
    env = gym.make(ENV_NAME)
    obs_space = env.observation_space
    act_space = env.action_space

    obs_dim = obs_space.shape[0]
    n_actions = act_space.n

    # Mạng online & target
    q_online = QNetwork(obs_dim, n_actions).to(DEVICE)
    q_target = QNetwork(obs_dim, n_actions).to(DEVICE)
    q_target.load_state_dict(q_online.state_dict())
    q_target.eval()

    optimizer = optim.Adam(q_online.parameters(), lr=LR)
    replay_buffer = ReplayBuffer(BUFFER_CAPACITY)

    eps = EPS_START
    global_step = 0

    for episode in range(1, MAX_EPISODES + 1):
        reset_out = env.reset()
        if isinstance(reset_out, tuple):
            state, _ = reset_out
        else:
            state = reset_out

        episode_return = 0.0
        episode_len = 0

        while True:
            global_step += 1

            # 1) chọn action theo ε-greedy
            action = select_action(q_online, state, eps, env)

            # 2) bước môi trường
            step_out = env.step(action)
            if len(step_out) == 5:
                next_state, reward, terminated, truncated, _ = step_out
                done = terminated or truncated
            else:
                next_state, reward, done, _ = step_out

            # 3) lưu transition
            replay_buffer.push(state, action, reward, next_state, float(done))

            state = next_state
            episode_return += reward
            episode_len += 1

            # 4) Train ONLINE nếu đủ điều kiện
            if global_step > WARMUP_STEPS and global_step % TRAIN_EVERY == 0:
                train_step(q_online, q_target, optimizer, replay_buffer)

            # 5) Cập nhật TARGET mỗi TARGET_UPDATE_EVERY step
            if global_step % TARGET_UPDATE_EVERY == 0:
                q_target.load_state_dict(q_online.state_dict())

            # 6) Giảm epsilon + log
            if done:
                eps = max(EPS_END, eps * EPS_DECAY)
                print(
                    f"Episode {episode:03d} | Return: {episode_return:6.1f} "
                    f"| Len: {episode_len:4d} | eps: {eps:.3f}"
                )
                break
    env.close()
    record_env = gym.make(ENV_NAME, render_mode="rgb_array")
    record_policy(record_env, q_online, eps=0.0)

# %% [markdown]
# # Main

# %%
if __name__ == "__main__":
    main()
# Out:
# Episode 001 | Return:   18.0 | Len:   18 | eps: 0.995
# Episode 002 | Return:   23.0 | Len:   23 | eps: 0.990
# Episode 003 | Return:   24.0 | Len:   24 | eps: 0.985
# Episode 004 | Return:   15.0 | Len:   15 | eps: 0.980
# Episode 005 | Return:   10.0 | Len:   10 | eps: 0.975
# Episode 006 | Return:   14.0 | Len:   14 | eps: 0.970
# Episode 007 | Return:   12.0 | Len:   12 | eps: 0.966
# Episode 008 | Return:   14.0 | Len:   14 | eps: 0.961
# Episode 009 | Return:   40.0 | Len:   40 | eps: 0.956
# Episode 010 | Return:   19.0 | Len:   19 | eps: 0.951
# Episode 011 | Return:   17.0 | Len:   17 | eps: 0.946
# Episode 012 | Return:   15.0 | Len:   15 | eps: 0.942
# Episode 013 | Return:   30.0 | Len:   30 | eps: 0.937
# Episode 014 | Return:   32.0 | Len:   32 | eps: 0.932
# Episode 015 | Return:   20.0 | Len:   20 | eps: 0.928
# Episode 016 | Return:   20.0 | Len:   20 | eps: 0.923
# Episode 017 | Return:   13.0 | Len:   13 | eps: 0.918
# Episode 018 | Return:   17.0 | Len:   17 | eps: 0.914
# Episode 019 | Return:   13.0 | Len:   13 | eps: 0.909
# Episode 020 | Return:   27.0 | Len:   27 | eps: 0.905
# Episode 021 | Return:   20.0 | Len:   20 | eps: 0.900
# Episode 022 | Return:   18.0 | Len:   18 | eps: 0.896
# Episode 023 | Return:   26.0 | Len:   26 | eps: 0.891
# Episode 024 | Return:   17.0 | Len:   17 | eps: 0.887
# Episode 025 | Return:   27.0 | Len:   27 | eps: 0.882
# Episode 026 | Return:   16.0 | Len:   16 | eps: 0.878
# Episode 027 | Return:   11.0 | Len:   11 | eps: 0.873
# Episode 028 | Return:   25.0 | Len:   25 | eps: 0.869
# Episode 029 | Return:   11.0 | Len:   11 | eps: 0.865
# Episode 030 | Return:   20.0 | Len:   20 | eps: 0.860
# Episode 031 | Return:   15.0 | Len:   15 | eps: 0.856
# Episode 032 | Return:   14.0 | Len:   14 | eps: 0.852
# Episode 033 | Return:   16.0 | Len:   16 | eps: 0.848
# Episode 034 | Return:   36.0 | Len:   36 | eps: 0.843
# Episode 035 | Return:   27.0 | Len:   27 | eps: 0.839
# Episode 036 | Return:   19.0 | Len:   19 | eps: 0.835
# Episode 037 | Return:   15.0 | Len:   15 | eps: 0.831
# Episode 038 | Return:   19.0 | Len:   19 | eps: 0.827
# Episode 039 | Return:   14.0 | Len:   14 | eps: 0.822
# Episode 040 | Return:   19.0 | Len:   19 | eps: 0.818
# Episode 041 | Return:   20.0 | Len:   20 | eps: 0.814
# Episode 042 | Return:   13.0 | Len:   13 | eps: 0.810
# Episode 043 | Return:   18.0 | Len:   18 | eps: 0.806
# Episode 044 | Return:   12.0 | Len:   12 | eps: 0.802
# Episode 045 | Return:   21.0 | Len:   21 | eps: 0.798
# Episode 046 | Return:   10.0 | Len:   10 | eps: 0.794
# Episode 047 | Return:   17.0 | Len:   17 | eps: 0.790
# Episode 048 | Return:   26.0 | Len:   26 | eps: 0.786
# Episode 049 | Return:   23.0 | Len:   23 | eps: 0.782
# Episode 050 | Return:   19.0 | Len:   19 | eps: 0.778
# Episode 051 | Return:   14.0 | Len:   14 | eps: 0.774
# Episode 052 | Return:   54.0 | Len:   54 | eps: 0.771
# Episode 053 | Return:   22.0 | Len:   22 | eps: 0.767
# Episode 054 | Return:   14.0 | Len:   14 | eps: 0.763
# Episode 055 | Return:   13.0 | Len:   13 | eps: 0.759
# Episode 056 | Return:   67.0 | Len:   67 | eps: 0.755
# Episode 057 | Return:   12.0 | Len:   12 | eps: 0.751
# Episode 058 | Return:   11.0 | Len:   11 | eps: 0.748
# Episode 059 | Return:   29.0 | Len:   29 | eps: 0.744
# Episode 060 | Return:   21.0 | Len:   21 | eps: 0.740
# Episode 061 | Return:   20.0 | Len:   20 | eps: 0.737
# Episode 062 | Return:   10.0 | Len:   10 | eps: 0.733
# Episode 063 | Return:   13.0 | Len:   13 | eps: 0.729
# Episode 064 | Return:   49.0 | Len:   49 | eps: 0.726
# Episode 065 | Return:   16.0 | Len:   16 | eps: 0.722
# Episode 066 | Return:   17.0 | Len:   17 | eps: 0.718
# Episode 067 | Return:    9.0 | Len:    9 | eps: 0.715
# Episode 068 | Return:   24.0 | Len:   24 | eps: 0.711
# Episode 069 | Return:   43.0 | Len:   43 | eps: 0.708
# Episode 070 | Return:   13.0 | Len:   13 | eps: 0.704
# Episode 071 | Return:   46.0 | Len:   46 | eps: 0.701
# Episode 072 | Return:   23.0 | Len:   23 | eps: 0.697
# Episode 073 | Return:   32.0 | Len:   32 | eps: 0.694
# Episode 074 | Return:   11.0 | Len:   11 | eps: 0.690
# Episode 075 | Return:    9.0 | Len:    9 | eps: 0.687
# Episode 076 | Return:   42.0 | Len:   42 | eps: 0.683
# Episode 077 | Return:   35.0 | Len:   35 | eps: 0.680
# Episode 078 | Return:   21.0 | Len:   21 | eps: 0.676
# Episode 079 | Return:   12.0 | Len:   12 | eps: 0.673
# Episode 080 | Return:   13.0 | Len:   13 | eps: 0.670
# Episode 081 | Return:   18.0 | Len:   18 | eps: 0.666
# Episode 082 | Return:   27.0 | Len:   27 | eps: 0.663
# Episode 083 | Return:   35.0 | Len:   35 | eps: 0.660
# Episode 084 | Return:   50.0 | Len:   50 | eps: 0.656
# Episode 085 | Return:   12.0 | Len:   12 | eps: 0.653
# Episode 086 | Return:   13.0 | Len:   13 | eps: 0.650
# Episode 087 | Return:   13.0 | Len:   13 | eps: 0.647
# Episode 088 | Return:   59.0 | Len:   59 | eps: 0.643
# Episode 089 | Return:   11.0 | Len:   11 | eps: 0.640
# Episode 090 | Return:   12.0 | Len:   12 | eps: 0.637
# Episode 091 | Return:   13.0 | Len:   13 | eps: 0.634
# Episode 092 | Return:   12.0 | Len:   12 | eps: 0.631
# Episode 093 | Return:   12.0 | Len:   12 | eps: 0.627
# Episode 094 | Return:   34.0 | Len:   34 | eps: 0.624
# Episode 095 | Return:   15.0 | Len:   15 | eps: 0.621
# Episode 096 | Return:   15.0 | Len:   15 | eps: 0.618
# Episode 097 | Return:   24.0 | Len:   24 | eps: 0.615
# Episode 098 | Return:    9.0 | Len:    9 | eps: 0.612
# Episode 099 | Return:   15.0 | Len:   15 | eps: 0.609
# Episode 100 | Return:   12.0 | Len:   12 | eps: 0.606
# Episode 101 | Return:   13.0 | Len:   13 | eps: 0.603
# Episode 102 | Return:   28.0 | Len:   28 | eps: 0.600
# Episode 103 | Return:   19.0 | Len:   19 | eps: 0.597
# Episode 104 | Return:   13.0 | Len:   13 | eps: 0.594
# Episode 105 | Return:   12.0 | Len:   12 | eps: 0.591
# Episode 106 | Return:   26.0 | Len:   26 | eps: 0.588
# Episode 107 | Return:   10.0 | Len:   10 | eps: 0.585
# Episode 108 | Return:   13.0 | Len:   13 | eps: 0.582
# Episode 109 | Return:   18.0 | Len:   18 | eps: 0.579
# Episode 110 | Return:   16.0 | Len:   16 | eps: 0.576
# Episode 111 | Return:   13.0 | Len:   13 | eps: 0.573
# Episode 112 | Return:    8.0 | Len:    8 | eps: 0.570
# Episode 113 | Return:   11.0 | Len:   11 | eps: 0.568
# Episode 114 | Return:   12.0 | Len:   12 | eps: 0.565
# Episode 115 | Return:   16.0 | Len:   16 | eps: 0.562
# Episode 116 | Return:   11.0 | Len:   11 | eps: 0.559
# Episode 117 | Return:   26.0 | Len:   26 | eps: 0.556
# Episode 118 | Return:   15.0 | Len:   15 | eps: 0.554
# Episode 119 | Return:   17.0 | Len:   17 | eps: 0.551
# Episode 120 | Return:   16.0 | Len:   16 | eps: 0.548
# Episode 121 | Return:   10.0 | Len:   10 | eps: 0.545
# Episode 122 | Return:   14.0 | Len:   14 | eps: 0.543
# Episode 123 | Return:   13.0 | Len:   13 | eps: 0.540
# Episode 124 | Return:    9.0 | Len:    9 | eps: 0.537
# Episode 125 | Return:    9.0 | Len:    9 | eps: 0.534
# Episode 126 | Return:   11.0 | Len:   11 | eps: 0.532
# Episode 127 | Return:   14.0 | Len:   14 | eps: 0.529
# Episode 128 | Return:   11.0 | Len:   11 | eps: 0.526
# Episode 129 | Return:   12.0 | Len:   12 | eps: 0.524
# Episode 130 | Return:   13.0 | Len:   13 | eps: 0.521
# Episode 131 | Return:   19.0 | Len:   19 | eps: 0.519
# Episode 132 | Return:   11.0 | Len:   11 | eps: 0.516
# Episode 133 | Return:   11.0 | Len:   11 | eps: 0.513
# Episode 134 | Return:   12.0 | Len:   12 | eps: 0.511
# Episode 135 | Return:    8.0 | Len:    8 | eps: 0.508
# Episode 136 | Return:   18.0 | Len:   18 | eps: 0.506
# Episode 137 | Return:   10.0 | Len:   10 | eps: 0.503
# Episode 138 | Return:   16.0 | Len:   16 | eps: 0.501
# Episode 139 | Return:   35.0 | Len:   35 | eps: 0.498
# Episode 140 | Return:   10.0 | Len:   10 | eps: 0.496
# Episode 141 | Return:   11.0 | Len:   11 | eps: 0.493
# Episode 142 | Return:   14.0 | Len:   14 | eps: 0.491
# Episode 143 | Return:   17.0 | Len:   17 | eps: 0.488
# Episode 144 | Return:   12.0 | Len:   12 | eps: 0.486
# Episode 145 | Return:   13.0 | Len:   13 | eps: 0.483
# Episode 146 | Return:   16.0 | Len:   16 | eps: 0.481
# Episode 147 | Return:   28.0 | Len:   28 | eps: 0.479
# Episode 148 | Return:   21.0 | Len:   21 | eps: 0.476
# Episode 149 | Return:   10.0 | Len:   10 | eps: 0.474
# Episode 150 | Return:   10.0 | Len:   10 | eps: 0.471
# Episode 151 | Return:    8.0 | Len:    8 | eps: 0.469
# Episode 152 | Return:    9.0 | Len:    9 | eps: 0.467
# Episode 153 | Return:   14.0 | Len:   14 | eps: 0.464
# Episode 154 | Return:   16.0 | Len:   16 | eps: 0.462
# Episode 155 | Return:   10.0 | Len:   10 | eps: 0.460
# Episode 156 | Return:   11.0 | Len:   11 | eps: 0.458
# Episode 157 | Return:   16.0 | Len:   16 | eps: 0.455
# Episode 158 | Return:   17.0 | Len:   17 | eps: 0.453
# Episode 159 | Return:   12.0 | Len:   12 | eps: 0.451
# Episode 160 | Return:   10.0 | Len:   10 | eps: 0.448
# Episode 161 | Return:   17.0 | Len:   17 | eps: 0.446
# Episode 162 | Return:   11.0 | Len:   11 | eps: 0.444
# Episode 163 | Return:   12.0 | Len:   12 | eps: 0.442
# Episode 164 | Return:   11.0 | Len:   11 | eps: 0.440
# Episode 165 | Return:   11.0 | Len:   11 | eps: 0.437
# Episode 166 | Return:    8.0 | Len:    8 | eps: 0.435
# Episode 167 | Return:   16.0 | Len:   16 | eps: 0.433
# Episode 168 | Return:   11.0 | Len:   11 | eps: 0.431
# Episode 169 | Return:   14.0 | Len:   14 | eps: 0.429
# Episode 170 | Return:   12.0 | Len:   12 | eps: 0.427
# Episode 171 | Return:   40.0 | Len:   40 | eps: 0.424
# Episode 172 | Return:   11.0 | Len:   11 | eps: 0.422
# Episode 173 | Return:   12.0 | Len:   12 | eps: 0.420
# Episode 174 | Return:   13.0 | Len:   13 | eps: 0.418
# Episode 175 | Return:   10.0 | Len:   10 | eps: 0.416
# Episode 176 | Return:   41.0 | Len:   41 | eps: 0.414
# Episode 177 | Return:   17.0 | Len:   17 | eps: 0.412
# Episode 178 | Return:   40.0 | Len:   40 | eps: 0.410
# Episode 179 | Return:   39.0 | Len:   39 | eps: 0.408
# Episode 180 | Return:   16.0 | Len:   16 | eps: 0.406
# Episode 181 | Return:   12.0 | Len:   12 | eps: 0.404
# Episode 182 | Return:   13.0 | Len:   13 | eps: 0.402
# Episode 183 | Return:   44.0 | Len:   44 | eps: 0.400
# Episode 184 | Return:   41.0 | Len:   41 | eps: 0.398
# Episode 185 | Return:   14.0 | Len:   14 | eps: 0.396
# Episode 186 | Return:   27.0 | Len:   27 | eps: 0.394
# Episode 187 | Return:   15.0 | Len:   15 | eps: 0.392
# Episode 188 | Return:   48.0 | Len:   48 | eps: 0.390
# Episode 189 | Return:   16.0 | Len:   16 | eps: 0.388
# Episode 190 | Return:   18.0 | Len:   18 | eps: 0.386
# Episode 191 | Return:   16.0 | Len:   16 | eps: 0.384
# Episode 192 | Return:   14.0 | Len:   14 | eps: 0.382
# Episode 193 | Return:   36.0 | Len:   36 | eps: 0.380
# Episode 194 | Return:   17.0 | Len:   17 | eps: 0.378
# Episode 195 | Return:   16.0 | Len:   16 | eps: 0.376
# Episode 196 | Return:   14.0 | Len:   14 | eps: 0.374
# Episode 197 | Return:   29.0 | Len:   29 | eps: 0.373
# Episode 198 | Return:   38.0 | Len:   38 | eps: 0.371
# Episode 199 | Return:   18.0 | Len:   18 | eps: 0.369
# Episode 200 | Return:   80.0 | Len:   80 | eps: 0.367
# Episode 201 | Return:   19.0 | Len:   19 | eps: 0.365
# Episode 202 | Return:   14.0 | Len:   14 | eps: 0.363
# Episode 203 | Return:   17.0 | Len:   17 | eps: 0.361
# Episode 204 | Return:   15.0 | Len:   15 | eps: 0.360
# Episode 205 | Return:   20.0 | Len:   20 | eps: 0.358
# Episode 206 | Return:   33.0 | Len:   33 | eps: 0.356
# Episode 207 | Return:   30.0 | Len:   30 | eps: 0.354
# Episode 208 | Return:  123.0 | Len:  123 | eps: 0.353
# Episode 209 | Return:   21.0 | Len:   21 | eps: 0.351
# Episode 210 | Return:   16.0 | Len:   16 | eps: 0.349
# Episode 211 | Return:   51.0 | Len:   51 | eps: 0.347
# Episode 212 | Return:   19.0 | Len:   19 | eps: 0.346
# Episode 213 | Return:   11.0 | Len:   11 | eps: 0.344
# Episode 214 | Return:   61.0 | Len:   61 | eps: 0.342
# Episode 215 | Return:   13.0 | Len:   13 | eps: 0.340
# Episode 216 | Return:   12.0 | Len:   12 | eps: 0.339
# Episode 217 | Return:   15.0 | Len:   15 | eps: 0.337
# Episode 218 | Return:   30.0 | Len:   30 | eps: 0.335
# Episode 219 | Return:   40.0 | Len:   40 | eps: 0.334
# Episode 220 | Return:   13.0 | Len:   13 | eps: 0.332
# Episode 221 | Return:   10.0 | Len:   10 | eps: 0.330
# Episode 222 | Return:   31.0 | Len:   31 | eps: 0.329
# Episode 223 | Return:   20.0 | Len:   20 | eps: 0.327
# Episode 224 | Return:   15.0 | Len:   15 | eps: 0.325
# Episode 225 | Return:   16.0 | Len:   16 | eps: 0.324
# Episode 226 | Return:   19.0 | Len:   19 | eps: 0.322
# Episode 227 | Return:   16.0 | Len:   16 | eps: 0.321
# Episode 228 | Return:   16.0 | Len:   16 | eps: 0.319
# Episode 229 | Return:   16.0 | Len:   16 | eps: 0.317
# Episode 230 | Return:   12.0 | Len:   12 | eps: 0.316
# Episode 231 | Return:   14.0 | Len:   14 | eps: 0.314
# Episode 232 | Return:   15.0 | Len:   15 | eps: 0.313
# Episode 233 | Return:   68.0 | Len:   68 | eps: 0.311
# Episode 234 | Return:   13.0 | Len:   13 | eps: 0.309
# Episode 235 | Return:   17.0 | Len:   17 | eps: 0.308
# Episode 236 | Return:   78.0 | Len:   78 | eps: 0.306
# Episode 237 | Return:   21.0 | Len:   21 | eps: 0.305
# Episode 238 | Return:   19.0 | Len:   19 | eps: 0.303
# Episode 239 | Return:   65.0 | Len:   65 | eps: 0.302
# Episode 240 | Return:   69.0 | Len:   69 | eps: 0.300
# Episode 241 | Return:   17.0 | Len:   17 | eps: 0.299
# Episode 242 | Return:   17.0 | Len:   17 | eps: 0.297
# Episode 243 | Return:   51.0 | Len:   51 | eps: 0.296
# Episode 244 | Return:   10.0 | Len:   10 | eps: 0.294
# Episode 245 | Return:   10.0 | Len:   10 | eps: 0.293
# Episode 246 | Return:   11.0 | Len:   11 | eps: 0.291
# Episode 247 | Return:   11.0 | Len:   11 | eps: 0.290
# Episode 248 | Return:   33.0 | Len:   33 | eps: 0.288
# Episode 249 | Return:   34.0 | Len:   34 | eps: 0.287
# Episode 250 | Return:   13.0 | Len:   13 | eps: 0.286
# Episode 251 | Return:   12.0 | Len:   12 | eps: 0.284
# Episode 252 | Return:   12.0 | Len:   12 | eps: 0.283
# Episode 253 | Return:   15.0 | Len:   15 | eps: 0.281
# Episode 254 | Return:  127.0 | Len:  127 | eps: 0.280
# Episode 255 | Return:   95.0 | Len:   95 | eps: 0.279
# Episode 256 | Return:   97.0 | Len:   97 | eps: 0.277
# Episode 257 | Return:   81.0 | Len:   81 | eps: 0.276
# Episode 258 | Return:   78.0 | Len:   78 | eps: 0.274
# Episode 259 | Return:   67.0 | Len:   67 | eps: 0.273
# Episode 260 | Return:  128.0 | Len:  128 | eps: 0.272
# Episode 261 | Return:   60.0 | Len:   60 | eps: 0.270
# Episode 262 | Return:   74.0 | Len:   74 | eps: 0.269
# Episode 263 | Return:   93.0 | Len:   93 | eps: 0.268
# Episode 264 | Return:   71.0 | Len:   71 | eps: 0.266
# Episode 265 | Return:   37.0 | Len:   37 | eps: 0.265
# Episode 266 | Return:   78.0 | Len:   78 | eps: 0.264
# Episode 267 | Return:  123.0 | Len:  123 | eps: 0.262
# Episode 268 | Return:  217.0 | Len:  217 | eps: 0.261
# Episode 269 | Return:  167.0 | Len:  167 | eps: 0.260
# Episode 270 | Return:  105.0 | Len:  105 | eps: 0.258
# Episode 271 | Return:  123.0 | Len:  123 | eps: 0.257
# Episode 272 | Return:  190.0 | Len:  190 | eps: 0.256
# Episode 273 | Return:  173.0 | Len:  173 | eps: 0.255
# Episode 274 | Return:   35.0 | Len:   35 | eps: 0.253
# Episode 275 | Return:  131.0 | Len:  131 | eps: 0.252
# Episode 276 | Return:  189.0 | Len:  189 | eps: 0.251
# Episode 277 | Return:  173.0 | Len:  173 | eps: 0.249
# Episode 278 | Return:   79.0 | Len:   79 | eps: 0.248
# Episode 279 | Return:   97.0 | Len:   97 | eps: 0.247
# Episode 280 | Return:  155.0 | Len:  155 | eps: 0.246
# Episode 281 | Return:  148.0 | Len:  148 | eps: 0.245
# Episode 282 | Return:  201.0 | Len:  201 | eps: 0.243
# Episode 283 | Return:  112.0 | Len:  112 | eps: 0.242
# Episode 284 | Return:  167.0 | Len:  167 | eps: 0.241
# Episode 285 | Return:  151.0 | Len:  151 | eps: 0.240
# Episode 286 | Return:  151.0 | Len:  151 | eps: 0.238
# Episode 287 | Return:  156.0 | Len:  156 | eps: 0.237
# Episode 288 | Return:  196.0 | Len:  196 | eps: 0.236
# Episode 289 | Return:  171.0 | Len:  171 | eps: 0.235
# Episode 290 | Return:  169.0 | Len:  169 | eps: 0.234
# Episode 291 | Return:   56.0 | Len:   56 | eps: 0.233
# Episode 292 | Return:  146.0 | Len:  146 | eps: 0.231
# Episode 293 | Return:  162.0 | Len:  162 | eps: 0.230
# Episode 294 | Return:  226.0 | Len:  226 | eps: 0.229
# Episode 295 | Return:  170.0 | Len:  170 | eps: 0.228
# Episode 296 | Return:  136.0 | Len:  136 | eps: 0.227
# Episode 297 | Return:  227.0 | Len:  227 | eps: 0.226
# Episode 298 | Return:  136.0 | Len:  136 | eps: 0.225
# Episode 299 | Return:  236.0 | Len:  236 | eps: 0.223
# Episode 300 | Return:  191.0 | Len:  191 | eps: 0.222
# Episode 301 | Return:  196.0 | Len:  196 | eps: 0.221
# Episode 302 | Return:  171.0 | Len:  171 | eps: 0.220
# Episode 303 | Return:  158.0 | Len:  158 | eps: 0.219
# Episode 304 | Return:  126.0 | Len:  126 | eps: 0.218
# Episode 305 | Return:  200.0 | Len:  200 | eps: 0.217
# Episode 306 | Return:  159.0 | Len:  159 | eps: 0.216
# Episode 307 | Return:  183.0 | Len:  183 | eps: 0.215
# Episode 308 | Return:  219.0 | Len:  219 | eps: 0.214
# Episode 309 | Return:  174.0 | Len:  174 | eps: 0.212
# Episode 310 | Return:  269.0 | Len:  269 | eps: 0.211
# Episode 311 | Return:  176.0 | Len:  176 | eps: 0.210
# Episode 312 | Return:  183.0 | Len:  183 | eps: 0.209
# Episode 313 | Return:  186.0 | Len:  186 | eps: 0.208
# Episode 314 | Return:  490.0 | Len:  490 | eps: 0.207
# Episode 315 | Return:  213.0 | Len:  213 | eps: 0.206
# Episode 316 | Return:  288.0 | Len:  288 | eps: 0.205
# Episode 317 | Return:  209.0 | Len:  209 | eps: 0.204
# Episode 318 | Return:  299.0 | Len:  299 | eps: 0.203
# Episode 319 | Return:  168.0 | Len:  168 | eps: 0.202
# Episode 320 | Return:  259.0 | Len:  259 | eps: 0.201
# Episode 321 | Return:  266.0 | Len:  266 | eps: 0.200
# Episode 322 | Return:  216.0 | Len:  216 | eps: 0.199
# Episode 323 | Return:  233.0 | Len:  233 | eps: 0.198
# Episode 324 | Return:  214.0 | Len:  214 | eps: 0.197
# Episode 325 | Return:  216.0 | Len:  216 | eps: 0.196
# Episode 326 | Return:  155.0 | Len:  155 | eps: 0.195
# Episode 327 | Return:  235.0 | Len:  235 | eps: 0.194
# Episode 328 | Return:  317.0 | Len:  317 | eps: 0.193
# Episode 329 | Return:  241.0 | Len:  241 | eps: 0.192
# Episode 330 | Return:  238.0 | Len:  238 | eps: 0.191
# Episode 331 | Return:   14.0 | Len:   14 | eps: 0.190
# Episode 332 | Return:  204.0 | Len:  204 | eps: 0.189
# Episode 333 | Return:  194.0 | Len:  194 | eps: 0.188
# Episode 334 | Return:  173.0 | Len:  173 | eps: 0.187
# Episode 335 | Return:  226.0 | Len:  226 | eps: 0.187
# Episode 336 | Return:  214.0 | Len:  214 | eps: 0.186
# Episode 337 | Return:  195.0 | Len:  195 | eps: 0.185
# Episode 338 | Return:  202.0 | Len:  202 | eps: 0.184
# Episode 339 | Return:  180.0 | Len:  180 | eps: 0.183
# Episode 340 | Return:  181.0 | Len:  181 | eps: 0.182
# Episode 341 | Return:  192.0 | Len:  192 | eps: 0.181
# Episode 342 | Return:  227.0 | Len:  227 | eps: 0.180
# Episode 343 | Return:  270.0 | Len:  270 | eps: 0.179
# Episode 344 | Return:  253.0 | Len:  253 | eps: 0.178
# Episode 345 | Return:  208.0 | Len:  208 | eps: 0.177
# Episode 346 | Return:  226.0 | Len:  226 | eps: 0.177
# Episode 347 | Return:  210.0 | Len:  210 | eps: 0.176
# Episode 348 | Return:  172.0 | Len:  172 | eps: 0.175
# Episode 349 | Return:  274.0 | Len:  274 | eps: 0.174
# Episode 350 | Return:  180.0 | Len:  180 | eps: 0.173
# Episode 351 | Return:  219.0 | Len:  219 | eps: 0.172
# Episode 352 | Return:  254.0 | Len:  254 | eps: 0.171
# Episode 353 | Return:  195.0 | Len:  195 | eps: 0.170
# Episode 354 | Return:  158.0 | Len:  158 | eps: 0.170
# Episode 355 | Return:   13.0 | Len:   13 | eps: 0.169
# Episode 356 | Return:  178.0 | Len:  178 | eps: 0.168
# Episode 357 | Return:  200.0 | Len:  200 | eps: 0.167
# Episode 358 | Return:  209.0 | Len:  209 | eps: 0.166
# Episode 359 | Return:  164.0 | Len:  164 | eps: 0.165
# Episode 360 | Return:  134.0 | Len:  134 | eps: 0.165
# Episode 361 | Return:  202.0 | Len:  202 | eps: 0.164
# Episode 362 | Return:  165.0 | Len:  165 | eps: 0.163
# Episode 363 | Return:  150.0 | Len:  150 | eps: 0.162
# Episode 364 | Return:  167.0 | Len:  167 | eps: 0.161
# Episode 365 | Return:  178.0 | Len:  178 | eps: 0.160
# Episode 366 | Return:  213.0 | Len:  213 | eps: 0.160
# Episode 367 | Return:  157.0 | Len:  157 | eps: 0.159
# Episode 368 | Return:  139.0 | Len:  139 | eps: 0.158
# Episode 369 | Return:  188.0 | Len:  188 | eps: 0.157
# Episode 370 | Return:  168.0 | Len:  168 | eps: 0.157
# Episode 371 | Return:  194.0 | Len:  194 | eps: 0.156
# Episode 372 | Return:  119.0 | Len:  119 | eps: 0.155
# Episode 373 | Return:  311.0 | Len:  311 | eps: 0.154
# Episode 374 | Return:  176.0 | Len:  176 | eps: 0.153
# Episode 375 | Return:  163.0 | Len:  163 | eps: 0.153
# Episode 376 | Return:  160.0 | Len:  160 | eps: 0.152
# Episode 377 | Return:  246.0 | Len:  246 | eps: 0.151
# Episode 378 | Return:  160.0 | Len:  160 | eps: 0.150
# Episode 379 | Return:  153.0 | Len:  153 | eps: 0.150
# Episode 380 | Return:  126.0 | Len:  126 | eps: 0.149
# Episode 381 | Return:  156.0 | Len:  156 | eps: 0.148
# Episode 382 | Return:  168.0 | Len:  168 | eps: 0.147
# Episode 383 | Return:  161.0 | Len:  161 | eps: 0.147
# Episode 384 | Return:  169.0 | Len:  169 | eps: 0.146
# Episode 385 | Return:  228.0 | Len:  228 | eps: 0.145
# Episode 386 | Return:  158.0 | Len:  158 | eps: 0.144
# Episode 387 | Return:  147.0 | Len:  147 | eps: 0.144
# Episode 388 | Return:  148.0 | Len:  148 | eps: 0.143
# Episode 389 | Return:  193.0 | Len:  193 | eps: 0.142
# Episode 390 | Return:  159.0 | Len:  159 | eps: 0.142
# Episode 391 | Return:  197.0 | Len:  197 | eps: 0.141
# Episode 392 | Return:  145.0 | Len:  145 | eps: 0.140
# Episode 393 | Return:  199.0 | Len:  199 | eps: 0.139
# Episode 394 | Return:  156.0 | Len:  156 | eps: 0.139
# Episode 395 | Return:  196.0 | Len:  196 | eps: 0.138
# Episode 396 | Return:  165.0 | Len:  165 | eps: 0.137
# Episode 397 | Return:  162.0 | Len:  162 | eps: 0.137
# Episode 398 | Return:  143.0 | Len:  143 | eps: 0.136
# Episode 399 | Return:  137.0 | Len:  137 | eps: 0.135
# Episode 400 | Return:  149.0 | Len:  149 | eps: 0.135
# Episode 401 | Return:  170.0 | Len:  170 | eps: 0.134
# Episode 402 | Return:  135.0 | Len:  135 | eps: 0.133
# Episode 403 | Return:  101.0 | Len:  101 | eps: 0.133
# Episode 404 | Return:  140.0 | Len:  140 | eps: 0.132
# Episode 405 | Return:  116.0 | Len:  116 | eps: 0.131
# Episode 406 | Return:  134.0 | Len:  134 | eps: 0.131
# Episode 407 | Return:  140.0 | Len:  140 | eps: 0.130
# Episode 408 | Return:  118.0 | Len:  118 | eps: 0.129
# Episode 409 | Return:  154.0 | Len:  154 | eps: 0.129
# Episode 410 | Return:  127.0 | Len:  127 | eps: 0.128
# Episode 411 | Return:  123.0 | Len:  123 | eps: 0.127
# Episode 412 | Return:  120.0 | Len:  120 | eps: 0.127
# Episode 413 | Return:  136.0 | Len:  136 | eps: 0.126
# Episode 414 | Return:  149.0 | Len:  149 | eps: 0.126
# Episode 415 | Return:  136.0 | Len:  136 | eps: 0.125
# Episode 416 | Return:  151.0 | Len:  151 | eps: 0.124
# Episode 417 | Return:  124.0 | Len:  124 | eps: 0.124
# Episode 418 | Return:  155.0 | Len:  155 | eps: 0.123
# Episode 419 | Return:  147.0 | Len:  147 | eps: 0.122
# Episode 420 | Return:  131.0 | Len:  131 | eps: 0.122
# Episode 421 | Return:  129.0 | Len:  129 | eps: 0.121
# Episode 422 | Return:  122.0 | Len:  122 | eps: 0.121
# Episode 423 | Return:  135.0 | Len:  135 | eps: 0.120
# Episode 424 | Return:  125.0 | Len:  125 | eps: 0.119
# Episode 425 | Return:  112.0 | Len:  112 | eps: 0.119
# Episode 426 | Return:  116.0 | Len:  116 | eps: 0.118
# Episode 427 | Return:  121.0 | Len:  121 | eps: 0.118
# Episode 428 | Return:  112.0 | Len:  112 | eps: 0.117
# Episode 429 | Return:  120.0 | Len:  120 | eps: 0.116
# Episode 430 | Return:  117.0 | Len:  117 | eps: 0.116
# Episode 431 | Return:   75.0 | Len:   75 | eps: 0.115
# Episode 432 | Return:   11.0 | Len:   11 | eps: 0.115
# Episode 433 | Return:   12.0 | Len:   12 | eps: 0.114
# Episode 434 | Return:   11.0 | Len:   11 | eps: 0.114
# Episode 435 | Return:  118.0 | Len:  118 | eps: 0.113
# Episode 436 | Return:  112.0 | Len:  112 | eps: 0.112
# Episode 437 | Return:  118.0 | Len:  118 | eps: 0.112
# Episode 438 | Return:  109.0 | Len:  109 | eps: 0.111
# Episode 439 | Return:  110.0 | Len:  110 | eps: 0.111
# Episode 440 | Return:  115.0 | Len:  115 | eps: 0.110
# Episode 441 | Return:  123.0 | Len:  123 | eps: 0.110
# Episode 442 | Return:  103.0 | Len:  103 | eps: 0.109
# Episode 443 | Return:  121.0 | Len:  121 | eps: 0.109
# Episode 444 | Return:  110.0 | Len:  110 | eps: 0.108
# Episode 445 | Return:  108.0 | Len:  108 | eps: 0.107
# Episode 446 | Return:  111.0 | Len:  111 | eps: 0.107
# Episode 447 | Return:  117.0 | Len:  117 | eps: 0.106
# Episode 448 | Return:  114.0 | Len:  114 | eps: 0.106
# Episode 449 | Return:  116.0 | Len:  116 | eps: 0.105
# Episode 450 | Return:  118.0 | Len:  118 | eps: 0.105
# Episode 451 | Return:  113.0 | Len:  113 | eps: 0.104
# Episode 452 | Return:  113.0 | Len:  113 | eps: 0.104
# Episode 453 | Return:  108.0 | Len:  108 | eps: 0.103
# Episode 454 | Return:  116.0 | Len:  116 | eps: 0.103
# Episode 455 | Return:   97.0 | Len:   97 | eps: 0.102
# Episode 456 | Return:   91.0 | Len:   91 | eps: 0.102
# Episode 457 | Return:  102.0 | Len:  102 | eps: 0.101
# Episode 458 | Return:  109.0 | Len:  109 | eps: 0.101
# Episode 459 | Return:  104.0 | Len:  104 | eps: 0.100
# Episode 460 | Return:  120.0 | Len:  120 | eps: 0.100
# Episode 461 | Return:  108.0 | Len:  108 | eps: 0.099
# Episode 462 | Return:  114.0 | Len:  114 | eps: 0.099
# Episode 463 | Return:  111.0 | Len:  111 | eps: 0.098
# Episode 464 | Return:   13.0 | Len:   13 | eps: 0.098
# Episode 465 | Return:  100.0 | Len:  100 | eps: 0.097
# Episode 466 | Return:  111.0 | Len:  111 | eps: 0.097
# Episode 467 | Return:  102.0 | Len:  102 | eps: 0.096
# Episode 468 | Return:  104.0 | Len:  104 | eps: 0.096
# Episode 469 | Return:   99.0 | Len:   99 | eps: 0.095
# Episode 470 | Return:   92.0 | Len:   92 | eps: 0.095
# Episode 471 | Return:  103.0 | Len:  103 | eps: 0.094
# Episode 472 | Return:  110.0 | Len:  110 | eps: 0.094
# Episode 473 | Return:  106.0 | Len:  106 | eps: 0.093
# Episode 474 | Return:  111.0 | Len:  111 | eps: 0.093
# Episode 475 | Return:   52.0 | Len:   52 | eps: 0.092
# Episode 476 | Return:  106.0 | Len:  106 | eps: 0.092
# Episode 477 | Return:  101.0 | Len:  101 | eps: 0.092
# Episode 478 | Return:  106.0 | Len:  106 | eps: 0.091
# Episode 479 | Return:   95.0 | Len:   95 | eps: 0.091
# Episode 480 | Return:   99.0 | Len:   99 | eps: 0.090
# Episode 481 | Return:   37.0 | Len:   37 | eps: 0.090
# Episode 482 | Return:  115.0 | Len:  115 | eps: 0.089
# Episode 483 | Return:  101.0 | Len:  101 | eps: 0.089
# Episode 484 | Return:  103.0 | Len:  103 | eps: 0.088
# Episode 485 | Return:  104.0 | Len:  104 | eps: 0.088
# Episode 486 | Return:   99.0 | Len:   99 | eps: 0.088
# Episode 487 | Return:  105.0 | Len:  105 | eps: 0.087
# Episode 488 | Return:  101.0 | Len:  101 | eps: 0.087
# Episode 489 | Return:  110.0 | Len:  110 | eps: 0.086
# Episode 490 | Return:   99.0 | Len:   99 | eps: 0.086
# Episode 491 | Return:  101.0 | Len:  101 | eps: 0.085
# Episode 492 | Return:  106.0 | Len:  106 | eps: 0.085
# Episode 493 | Return:  102.0 | Len:  102 | eps: 0.084
# Episode 494 | Return:  111.0 | Len:  111 | eps: 0.084
# Episode 495 | Return:  104.0 | Len:  104 | eps: 0.084
# Episode 496 | Return:  103.0 | Len:  103 | eps: 0.083
# Episode 497 | Return:  106.0 | Len:  106 | eps: 0.083
# Episode 498 | Return:  104.0 | Len:  104 | eps: 0.082
# Episode 499 | Return:   99.0 | Len:   99 | eps: 0.082
# Episode 500 | Return:  100.0 | Len:  100 | eps: 0.082
# Episode 501 | Return:  103.0 | Len:  103 | eps: 0.081
# Episode 502 | Return:  108.0 | Len:  108 | eps: 0.081
# Episode 503 | Return:  102.0 | Len:  102 | eps: 0.080
# Episode 504 | Return:   98.0 | Len:   98 | eps: 0.080
# Episode 505 | Return:   14.0 | Len:   14 | eps: 0.080
# Episode 506 | Return:  118.0 | Len:  118 | eps: 0.079
# Episode 507 | Return:  101.0 | Len:  101 | eps: 0.079
# Episode 508 | Return:  114.0 | Len:  114 | eps: 0.078
# Episode 509 | Return:  103.0 | Len:  103 | eps: 0.078
# Episode 510 | Return:  108.0 | Len:  108 | eps: 0.078
# Episode 511 | Return:  104.0 | Len:  104 | eps: 0.077
# Episode 512 | Return:  107.0 | Len:  107 | eps: 0.077
# Episode 513 | Return:  109.0 | Len:  109 | eps: 0.076
# Episode 514 | Return:   14.0 | Len:   14 | eps: 0.076
# Episode 515 | Return:  103.0 | Len:  103 | eps: 0.076
# Episode 516 | Return:  114.0 | Len:  114 | eps: 0.075
# Episode 517 | Return:  115.0 | Len:  115 | eps: 0.075
# Episode 518 | Return:  113.0 | Len:  113 | eps: 0.075
# Episode 519 | Return:  112.0 | Len:  112 | eps: 0.074
# Episode 520 | Return:  110.0 | Len:  110 | eps: 0.074
# Episode 521 | Return:  111.0 | Len:  111 | eps: 0.073
# Episode 522 | Return:  104.0 | Len:  104 | eps: 0.073
# Episode 523 | Return:  118.0 | Len:  118 | eps: 0.073
# Episode 524 | Return:  111.0 | Len:  111 | eps: 0.072
# Episode 525 | Return:  104.0 | Len:  104 | eps: 0.072
# Episode 526 | Return:  114.0 | Len:  114 | eps: 0.072
# Episode 527 | Return:  112.0 | Len:  112 | eps: 0.071
# Episode 528 | Return:  111.0 | Len:  111 | eps: 0.071
# Episode 529 | Return:  106.0 | Len:  106 | eps: 0.071
# Episode 530 | Return:  101.0 | Len:  101 | eps: 0.070
# Episode 531 | Return:  105.0 | Len:  105 | eps: 0.070
# Episode 532 | Return:  106.0 | Len:  106 | eps: 0.069
# Episode 533 | Return:  107.0 | Len:  107 | eps: 0.069
# Episode 534 | Return:  145.0 | Len:  145 | eps: 0.069
# Episode 535 | Return:  103.0 | Len:  103 | eps: 0.068
# Episode 536 | Return:  111.0 | Len:  111 | eps: 0.068
# Episode 537 | Return:  124.0 | Len:  124 | eps: 0.068
# Episode 538 | Return:  113.0 | Len:  113 | eps: 0.067
# Episode 539 | Return:  107.0 | Len:  107 | eps: 0.067
# Episode 540 | Return:  127.0 | Len:  127 | eps: 0.067
# Episode 541 | Return:  117.0 | Len:  117 | eps: 0.066
# Episode 542 | Return:  107.0 | Len:  107 | eps: 0.066
# Episode 543 | Return:  112.0 | Len:  112 | eps: 0.066
# Episode 544 | Return:  111.0 | Len:  111 | eps: 0.065
# Episode 545 | Return:  106.0 | Len:  106 | eps: 0.065
# Episode 546 | Return:  108.0 | Len:  108 | eps: 0.065
# Episode 547 | Return:  116.0 | Len:  116 | eps: 0.064
# Episode 548 | Return:  110.0 | Len:  110 | eps: 0.064
# Episode 549 | Return:  103.0 | Len:  103 | eps: 0.064
# Episode 550 | Return:  102.0 | Len:  102 | eps: 0.063
# Episode 551 | Return:  103.0 | Len:  103 | eps: 0.063
# Episode 552 | Return:   97.0 | Len:   97 | eps: 0.063
# Episode 553 | Return:  102.0 | Len:  102 | eps: 0.063
# Episode 554 | Return:   39.0 | Len:   39 | eps: 0.062
# Episode 555 | Return:  101.0 | Len:  101 | eps: 0.062
# Episode 556 | Return:   11.0 | Len:   11 | eps: 0.062
# Episode 557 | Return:   97.0 | Len:   97 | eps: 0.061
# Episode 558 | Return:  100.0 | Len:  100 | eps: 0.061
# Episode 559 | Return:   95.0 | Len:   95 | eps: 0.061
# Episode 560 | Return:   99.0 | Len:   99 | eps: 0.060
# Episode 561 | Return:  104.0 | Len:  104 | eps: 0.060
# Episode 562 | Return:   97.0 | Len:   97 | eps: 0.060
# Episode 563 | Return:  136.0 | Len:  136 | eps: 0.059
# Episode 564 | Return:  100.0 | Len:  100 | eps: 0.059
# Episode 565 | Return:  103.0 | Len:  103 | eps: 0.059
# Episode 566 | Return:   96.0 | Len:   96 | eps: 0.059
# Episode 567 | Return:  108.0 | Len:  108 | eps: 0.058
# Episode 568 | Return:   99.0 | Len:   99 | eps: 0.058
# Episode 569 | Return:   99.0 | Len:   99 | eps: 0.058
# Episode 570 | Return:  181.0 | Len:  181 | eps: 0.057
# Episode 571 | Return:   97.0 | Len:   97 | eps: 0.057
# Episode 572 | Return:  104.0 | Len:  104 | eps: 0.057
# Episode 573 | Return:  240.0 | Len:  240 | eps: 0.057
# Episode 574 | Return:  101.0 | Len:  101 | eps: 0.056
# Episode 575 | Return:  101.0 | Len:  101 | eps: 0.056
# Episode 576 | Return:   96.0 | Len:   96 | eps: 0.056
# Episode 577 | Return:   98.0 | Len:   98 | eps: 0.055
# Episode 578 | Return:   25.0 | Len:   25 | eps: 0.055
# Episode 579 | Return:   95.0 | Len:   95 | eps: 0.055
# Episode 580 | Return:  104.0 | Len:  104 | eps: 0.055
# Episode 581 | Return:   98.0 | Len:   98 | eps: 0.054
# Episode 582 | Return:   96.0 | Len:   96 | eps: 0.054
# Episode 583 | Return:   41.0 | Len:   41 | eps: 0.054
# Episode 584 | Return:   95.0 | Len:   95 | eps: 0.054
# Episode 585 | Return:  100.0 | Len:  100 | eps: 0.053
# Episode 586 | Return:   96.0 | Len:   96 | eps: 0.053
# Episode 587 | Return:   99.0 | Len:   99 | eps: 0.053
# Episode 588 | Return:  103.0 | Len:  103 | eps: 0.052
# Episode 589 | Return:   97.0 | Len:   97 | eps: 0.052
# Episode 590 | Return:  103.0 | Len:  103 | eps: 0.052
# Episode 591 | Return:   96.0 | Len:   96 | eps: 0.052
# Episode 592 | Return:   99.0 | Len:   99 | eps: 0.051
# Episode 593 | Return:  102.0 | Len:  102 | eps: 0.051
# Episode 594 | Return:   98.0 | Len:   98 | eps: 0.051
# Episode 595 | Return:   98.0 | Len:   98 | eps: 0.051
# Episode 596 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 597 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 598 | Return:  126.0 | Len:  126 | eps: 0.050
# Episode 599 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 600 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 601 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 602 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 603 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 604 | Return:  106.0 | Len:  106 | eps: 0.050
# Episode 605 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 606 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 607 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 608 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 609 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 610 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 611 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 612 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 613 | Return:  131.0 | Len:  131 | eps: 0.050
# Episode 614 | Return:   45.0 | Len:   45 | eps: 0.050
# Episode 615 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 616 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 617 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 618 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 619 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 620 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 621 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 622 | Return:  107.0 | Len:  107 | eps: 0.050
# Episode 623 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 624 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 625 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 626 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 627 | Return:   29.0 | Len:   29 | eps: 0.050
# Episode 628 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 629 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 630 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 631 | Return:   13.0 | Len:   13 | eps: 0.050
# Episode 632 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 633 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 634 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 635 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 636 | Return:   41.0 | Len:   41 | eps: 0.050
# Episode 637 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 638 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 639 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 640 | Return:   92.0 | Len:   92 | eps: 0.050
# Episode 641 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 642 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 643 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 644 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 645 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 646 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 647 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 648 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 649 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 650 | Return:   19.0 | Len:   19 | eps: 0.050
# Episode 651 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 652 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 653 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 654 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 655 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 656 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 657 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 658 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 659 | Return:  107.0 | Len:  107 | eps: 0.050
# Episode 660 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 661 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 662 | Return:   54.0 | Len:   54 | eps: 0.050
# Episode 663 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 664 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 665 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 666 | Return:   38.0 | Len:   38 | eps: 0.050
# Episode 667 | Return:   37.0 | Len:   37 | eps: 0.050
# Episode 668 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 669 | Return:   88.0 | Len:   88 | eps: 0.050
# Episode 670 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 671 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 672 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 673 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 674 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 675 | Return:   89.0 | Len:   89 | eps: 0.050
# Episode 676 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 677 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 678 | Return:   16.0 | Len:   16 | eps: 0.050
# Episode 679 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 680 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 681 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 682 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 683 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 684 | Return:   28.0 | Len:   28 | eps: 0.050
# Episode 685 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 686 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 687 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 688 | Return:   34.0 | Len:   34 | eps: 0.050
# Episode 689 | Return:   90.0 | Len:   90 | eps: 0.050
# Episode 690 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 691 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 692 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 693 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 694 | Return:   91.0 | Len:   91 | eps: 0.050
# Episode 695 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 696 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 697 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 698 | Return:   56.0 | Len:   56 | eps: 0.050
# Episode 699 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 700 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 701 | Return:   26.0 | Len:   26 | eps: 0.050
# Episode 702 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 703 | Return:   86.0 | Len:   86 | eps: 0.050
# Episode 704 | Return:   27.0 | Len:   27 | eps: 0.050
# Episode 705 | Return:   89.0 | Len:   89 | eps: 0.050
# Episode 706 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 707 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 708 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 709 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 710 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 711 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 712 | Return:   91.0 | Len:   91 | eps: 0.050
# Episode 713 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 714 | Return:  105.0 | Len:  105 | eps: 0.050
# Episode 715 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 716 | Return:   90.0 | Len:   90 | eps: 0.050
# Episode 717 | Return:   41.0 | Len:   41 | eps: 0.050
# Episode 718 | Return:   28.0 | Len:   28 | eps: 0.050
# Episode 719 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 720 | Return:   92.0 | Len:   92 | eps: 0.050
# Episode 721 | Return:   11.0 | Len:   11 | eps: 0.050
# Episode 722 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 723 | Return:   52.0 | Len:   52 | eps: 0.050
# Episode 724 | Return:   91.0 | Len:   91 | eps: 0.050
# Episode 725 | Return:   25.0 | Len:   25 | eps: 0.050
# Episode 726 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 727 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 728 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 729 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 730 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 731 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 732 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 733 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 734 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 735 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 736 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 737 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 738 | Return:   88.0 | Len:   88 | eps: 0.050
# Episode 739 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 740 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 741 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 742 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 743 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 744 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 745 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 746 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 747 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 748 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 749 | Return:  107.0 | Len:  107 | eps: 0.050
# Episode 750 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 751 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 752 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 753 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 754 | Return:   16.0 | Len:   16 | eps: 0.050
# Episode 755 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 756 | Return:  110.0 | Len:  110 | eps: 0.050
# Episode 757 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 758 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 759 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 760 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 761 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 762 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 763 | Return:   22.0 | Len:   22 | eps: 0.050
# Episode 764 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 765 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 766 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 767 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 768 | Return:  108.0 | Len:  108 | eps: 0.050
# Episode 769 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 770 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 771 | Return:   31.0 | Len:   31 | eps: 0.050
# Episode 772 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 773 | Return:   24.0 | Len:   24 | eps: 0.050
# Episode 774 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 775 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 776 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 777 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 778 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 779 | Return:   41.0 | Len:   41 | eps: 0.050
# Episode 780 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 781 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 782 | Return:  110.0 | Len:  110 | eps: 0.050
# Episode 783 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 784 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 785 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 786 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 787 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 788 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 789 | Return:  106.0 | Len:  106 | eps: 0.050
# Episode 790 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 791 | Return:  104.0 | Len:  104 | eps: 0.050
# Episode 792 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 793 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 794 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 795 | Return:   23.0 | Len:   23 | eps: 0.050
# Episode 796 | Return:  108.0 | Len:  108 | eps: 0.050
# Episode 797 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 798 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 799 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 800 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 801 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 802 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 803 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 804 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 805 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 806 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 807 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 808 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 809 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 810 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 811 | Return:  104.0 | Len:  104 | eps: 0.050
# Episode 812 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 813 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 814 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 815 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 816 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 817 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 818 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 819 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 820 | Return:   30.0 | Len:   30 | eps: 0.050
# Episode 821 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 822 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 823 | Return:   45.0 | Len:   45 | eps: 0.050
# Episode 824 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 825 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 826 | Return:   19.0 | Len:   19 | eps: 0.050
# Episode 827 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 828 | Return:   89.0 | Len:   89 | eps: 0.050
# Episode 829 | Return:   22.0 | Len:   22 | eps: 0.050
# Episode 830 | Return:  105.0 | Len:  105 | eps: 0.050
# Episode 831 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 832 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 833 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 834 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 835 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 836 | Return:   11.0 | Len:   11 | eps: 0.050
# Episode 837 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 838 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 839 | Return:   38.0 | Len:   38 | eps: 0.050
# Episode 840 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 841 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 842 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 843 | Return:   11.0 | Len:   11 | eps: 0.050
# Episode 844 | Return:   35.0 | Len:   35 | eps: 0.050
# Episode 845 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 846 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 847 | Return:   16.0 | Len:   16 | eps: 0.050
# Episode 848 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 849 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 850 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 851 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 852 | Return:  109.0 | Len:  109 | eps: 0.050
# Episode 853 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 854 | Return:  107.0 | Len:  107 | eps: 0.050
# Episode 855 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 856 | Return:  112.0 | Len:  112 | eps: 0.050
# Episode 857 | Return:  112.0 | Len:  112 | eps: 0.050
# Episode 858 | Return:  105.0 | Len:  105 | eps: 0.050
# Episode 859 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 860 | Return:   32.0 | Len:   32 | eps: 0.050
# Episode 861 | Return:  107.0 | Len:  107 | eps: 0.050
# Episode 862 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 863 | Return:   40.0 | Len:   40 | eps: 0.050
# Episode 864 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 865 | Return:   40.0 | Len:   40 | eps: 0.050
# Episode 866 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 867 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 868 | Return:   44.0 | Len:   44 | eps: 0.050
# Episode 869 | Return:  102.0 | Len:  102 | eps: 0.050
# Episode 870 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 871 | Return:  108.0 | Len:  108 | eps: 0.050
# Episode 872 | Return:   18.0 | Len:   18 | eps: 0.050
# Episode 873 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 874 | Return:   98.0 | Len:   98 | eps: 0.050
# Episode 875 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 876 | Return:   40.0 | Len:   40 | eps: 0.050
# Episode 877 | Return:  104.0 | Len:  104 | eps: 0.050
# Episode 878 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 879 | Return:  109.0 | Len:  109 | eps: 0.050
# Episode 880 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 881 | Return:   13.0 | Len:   13 | eps: 0.050
# Episode 882 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 883 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 884 | Return:  111.0 | Len:  111 | eps: 0.050
# Episode 885 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 886 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 887 | Return:  109.0 | Len:  109 | eps: 0.050
# Episode 888 | Return:  113.0 | Len:  113 | eps: 0.050
# ...
# Episode 4717 | Return:  278.0 | Len:  278 | eps: 0.050
# Episode 4718 | Return:   14.0 | Len:   14 | eps: 0.050
# Episode 4719 | Return:   18.0 | Len:   18 | eps: 0.050
# Episode 4720 | Return:   31.0 | Len:   31 | eps: 0.050
# Episode 4721 | Return:  150.0 | Len:  150 | eps: 0.050
# Episode 4722 | Return:   14.0 | Len:   14 | eps: 0.050
# Episode 4723 | Return:   93.0 | Len:   93 | eps: 0.050
# Episode 4724 | Return:  111.0 | Len:  111 | eps: 0.050
# Episode 4725 | Return:  130.0 | Len:  130 | eps: 0.050
# Episode 4726 | Return:   14.0 | Len:   14 | eps: 0.050
# Episode 4727 | Return:  112.0 | Len:  112 | eps: 0.050
# Episode 4728 | Return:   18.0 | Len:   18 | eps: 0.050
# Episode 4729 | Return:  164.0 | Len:  164 | eps: 0.050
# Episode 4730 | Return:  104.0 | Len:  104 | eps: 0.050
# Episode 4731 | Return:   95.0 | Len:   95 | eps: 0.050
# Episode 4732 | Return:   56.0 | Len:   56 | eps: 0.050
# Episode 4733 | Return:   20.0 | Len:   20 | eps: 0.050
# Episode 4734 | Return:  104.0 | Len:  104 | eps: 0.050
# Episode 4735 | Return:  268.0 | Len:  268 | eps: 0.050
# Episode 4736 | Return:   19.0 | Len:   19 | eps: 0.050
# Episode 4737 | Return:  354.0 | Len:  354 | eps: 0.050
# Episode 4738 | Return:  136.0 | Len:  136 | eps: 0.050
# Episode 4739 | Return:  309.0 | Len:  309 | eps: 0.050
# Episode 4740 | Return:  312.0 | Len:  312 | eps: 0.050
# Episode 4741 | Return:   31.0 | Len:   31 | eps: 0.050
# Episode 4742 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 4743 | Return:  130.0 | Len:  130 | eps: 0.050
# Episode 4744 | Return:  109.0 | Len:  109 | eps: 0.050
# Episode 4745 | Return:  134.0 | Len:  134 | eps: 0.050
# Episode 4746 | Return:  114.0 | Len:  114 | eps: 0.050
# Episode 4747 | Return:   80.0 | Len:   80 | eps: 0.050
# Episode 4748 | Return:  351.0 | Len:  351 | eps: 0.050
# Episode 4749 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4750 | Return:   40.0 | Len:   40 | eps: 0.050
# Episode 4751 | Return:  143.0 | Len:  143 | eps: 0.050
# Episode 4752 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4753 | Return:   28.0 | Len:   28 | eps: 0.050
# Episode 4754 | Return:  173.0 | Len:  173 | eps: 0.050
# Episode 4755 | Return:   11.0 | Len:   11 | eps: 0.050
# Episode 4756 | Return:   72.0 | Len:   72 | eps: 0.050
# Episode 4757 | Return:  137.0 | Len:  137 | eps: 0.050
# Episode 4758 | Return:  186.0 | Len:  186 | eps: 0.050
# Episode 4759 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4760 | Return:  305.0 | Len:  305 | eps: 0.050
# Episode 4761 | Return:   57.0 | Len:   57 | eps: 0.050
# Episode 4762 | Return:   11.0 | Len:   11 | eps: 0.050
# Episode 4763 | Return:   88.0 | Len:   88 | eps: 0.050
# Episode 4764 | Return:   36.0 | Len:   36 | eps: 0.050
# Episode 4765 | Return:  138.0 | Len:  138 | eps: 0.050
# Episode 4766 | Return:   15.0 | Len:   15 | eps: 0.050
# Episode 4767 | Return:   23.0 | Len:   23 | eps: 0.050
# Episode 4768 | Return:  185.0 | Len:  185 | eps: 0.050
# Episode 4769 | Return:  187.0 | Len:  187 | eps: 0.050
# Episode 4770 | Return:   15.0 | Len:   15 | eps: 0.050
# Episode 4771 | Return:  182.0 | Len:  182 | eps: 0.050
# Episode 4772 | Return:   71.0 | Len:   71 | eps: 0.050
# Episode 4773 | Return:   53.0 | Len:   53 | eps: 0.050
# Episode 4774 | Return:   21.0 | Len:   21 | eps: 0.050
# Episode 4775 | Return:  320.0 | Len:  320 | eps: 0.050
# Episode 4776 | Return:   67.0 | Len:   67 | eps: 0.050
# Episode 4777 | Return:  147.0 | Len:  147 | eps: 0.050
# Episode 4778 | Return:   13.0 | Len:   13 | eps: 0.050
# Episode 4779 | Return:   12.0 | Len:   12 | eps: 0.050
# Episode 4780 | Return:   71.0 | Len:   71 | eps: 0.050
# Episode 4781 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 4782 | Return:   47.0 | Len:   47 | eps: 0.050
# Episode 4783 | Return:  226.0 | Len:  226 | eps: 0.050
# Episode 4784 | Return:   84.0 | Len:   84 | eps: 0.050
# Episode 4785 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 4786 | Return:   33.0 | Len:   33 | eps: 0.050
# Episode 4787 | Return:   84.0 | Len:   84 | eps: 0.050
# Episode 4788 | Return:   66.0 | Len:   66 | eps: 0.050
# Episode 4789 | Return:   42.0 | Len:   42 | eps: 0.050
# Episode 4790 | Return:   39.0 | Len:   39 | eps: 0.050
# Episode 4791 | Return:  115.0 | Len:  115 | eps: 0.050
# Episode 4792 | Return:   23.0 | Len:   23 | eps: 0.050
# Episode 4793 | Return:  136.0 | Len:  136 | eps: 0.050
# Episode 4794 | Return:   30.0 | Len:   30 | eps: 0.050
# Episode 4795 | Return:  107.0 | Len:  107 | eps: 0.050
# Episode 4796 | Return:  151.0 | Len:  151 | eps: 0.050
# Episode 4797 | Return:  166.0 | Len:  166 | eps: 0.050
# Episode 4798 | Return:  156.0 | Len:  156 | eps: 0.050
# Episode 4799 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4800 | Return:   14.0 | Len:   14 | eps: 0.050
# Episode 4801 | Return:   52.0 | Len:   52 | eps: 0.050
# Episode 4802 | Return:  275.0 | Len:  275 | eps: 0.050
# Episode 4803 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 4804 | Return:   39.0 | Len:   39 | eps: 0.050
# Episode 4805 | Return:   16.0 | Len:   16 | eps: 0.050
# Episode 4806 | Return:   18.0 | Len:   18 | eps: 0.050
# Episode 4807 | Return:  118.0 | Len:  118 | eps: 0.050
# Episode 4808 | Return:  219.0 | Len:  219 | eps: 0.050
# Episode 4809 | Return:  254.0 | Len:  254 | eps: 0.050
# Episode 4810 | Return:  202.0 | Len:  202 | eps: 0.050
# Episode 4811 | Return:  334.0 | Len:  334 | eps: 0.050
# Episode 4812 | Return:  105.0 | Len:  105 | eps: 0.050
# Episode 4813 | Return:  136.0 | Len:  136 | eps: 0.050
# Episode 4814 | Return:  293.0 | Len:  293 | eps: 0.050
# Episode 4815 | Return:  157.0 | Len:  157 | eps: 0.050
# Episode 4816 | Return:  174.0 | Len:  174 | eps: 0.050
# Episode 4817 | Return:  124.0 | Len:  124 | eps: 0.050
# Episode 4818 | Return:  194.0 | Len:  194 | eps: 0.050
# Episode 4819 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 4820 | Return:  206.0 | Len:  206 | eps: 0.050
# Episode 4821 | Return:  180.0 | Len:  180 | eps: 0.050
# Episode 4822 | Return:   79.0 | Len:   79 | eps: 0.050
# Episode 4823 | Return:  126.0 | Len:  126 | eps: 0.050
# Episode 4824 | Return:  260.0 | Len:  260 | eps: 0.050
# Episode 4825 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 4826 | Return:   12.0 | Len:   12 | eps: 0.050
# Episode 4827 | Return:   11.0 | Len:   11 | eps: 0.050
# Episode 4828 | Return:   94.0 | Len:   94 | eps: 0.050
# Episode 4829 | Return:  101.0 | Len:  101 | eps: 0.050
# Episode 4830 | Return:  130.0 | Len:  130 | eps: 0.050
# Episode 4831 | Return:  118.0 | Len:  118 | eps: 0.050
# Episode 4832 | Return:  151.0 | Len:  151 | eps: 0.050
# Episode 4833 | Return:  457.0 | Len:  457 | eps: 0.050
# Episode 4834 | Return:   61.0 | Len:   61 | eps: 0.050
# Episode 4835 | Return:   91.0 | Len:   91 | eps: 0.050
# Episode 4836 | Return:  175.0 | Len:  175 | eps: 0.050
# Episode 4837 | Return:  334.0 | Len:  334 | eps: 0.050
# Episode 4838 | Return:  214.0 | Len:  214 | eps: 0.050
# Episode 4839 | Return:  337.0 | Len:  337 | eps: 0.050
# Episode 4840 | Return:  140.0 | Len:  140 | eps: 0.050
# Episode 4841 | Return:   18.0 | Len:   18 | eps: 0.050
# Episode 4842 | Return:  432.0 | Len:  432 | eps: 0.050
# Episode 4843 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 4844 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4845 | Return:  378.0 | Len:  378 | eps: 0.050
# Episode 4846 | Return:   60.0 | Len:   60 | eps: 0.050
# Episode 4847 | Return:  103.0 | Len:  103 | eps: 0.050
# Episode 4848 | Return:   51.0 | Len:   51 | eps: 0.050
# Episode 4849 | Return:   62.0 | Len:   62 | eps: 0.050
# Episode 4850 | Return:  128.0 | Len:  128 | eps: 0.050
# Episode 4851 | Return:  120.0 | Len:  120 | eps: 0.050
# Episode 4852 | Return:  106.0 | Len:  106 | eps: 0.050
# Episode 4853 | Return:   12.0 | Len:   12 | eps: 0.050
# Episode 4854 | Return:   61.0 | Len:   61 | eps: 0.050
# Episode 4855 | Return:  147.0 | Len:  147 | eps: 0.050
# Episode 4856 | Return:   55.0 | Len:   55 | eps: 0.050
# Episode 4857 | Return:   18.0 | Len:   18 | eps: 0.050
# Episode 4858 | Return:  116.0 | Len:  116 | eps: 0.050
# Episode 4859 | Return:   18.0 | Len:   18 | eps: 0.050
# Episode 4860 | Return:  271.0 | Len:  271 | eps: 0.050
# Episode 4861 | Return:   97.0 | Len:   97 | eps: 0.050
# Episode 4862 | Return:  266.0 | Len:  266 | eps: 0.050
# Episode 4863 | Return:  134.0 | Len:  134 | eps: 0.050
# Episode 4864 | Return:   44.0 | Len:   44 | eps: 0.050
# Episode 4865 | Return:   85.0 | Len:   85 | eps: 0.050
# Episode 4866 | Return:   26.0 | Len:   26 | eps: 0.050
# Episode 4867 | Return:  112.0 | Len:  112 | eps: 0.050
# Episode 4868 | Return:   82.0 | Len:   82 | eps: 0.050
# Episode 4869 | Return:   56.0 | Len:   56 | eps: 0.050
# Episode 4870 | Return:   55.0 | Len:   55 | eps: 0.050
# Episode 4871 | Return:  107.0 | Len:  107 | eps: 0.050
# Episode 4872 | Return:   88.0 | Len:   88 | eps: 0.050
# Episode 4873 | Return:  364.0 | Len:  364 | eps: 0.050
# Episode 4874 | Return:  202.0 | Len:  202 | eps: 0.050
# Episode 4875 | Return:   18.0 | Len:   18 | eps: 0.050
# Episode 4876 | Return:  202.0 | Len:  202 | eps: 0.050
# Episode 4877 | Return:   46.0 | Len:   46 | eps: 0.050
# Episode 4878 | Return:   22.0 | Len:   22 | eps: 0.050
# Episode 4879 | Return:   71.0 | Len:   71 | eps: 0.050
# Episode 4880 | Return:  194.0 | Len:  194 | eps: 0.050
# Episode 4881 | Return:   25.0 | Len:   25 | eps: 0.050
# Episode 4882 | Return:  238.0 | Len:  238 | eps: 0.050
# Episode 4883 | Return:   25.0 | Len:   25 | eps: 0.050
# Episode 4884 | Return:  145.0 | Len:  145 | eps: 0.050
# Episode 4885 | Return:   84.0 | Len:   84 | eps: 0.050
# Episode 4886 | Return:  269.0 | Len:  269 | eps: 0.050
# Episode 4887 | Return:  209.0 | Len:  209 | eps: 0.050
# Episode 4888 | Return:   23.0 | Len:   23 | eps: 0.050
# Episode 4889 | Return:   42.0 | Len:   42 | eps: 0.050
# Episode 4890 | Return:   99.0 | Len:   99 | eps: 0.050
# Episode 4891 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4892 | Return:  368.0 | Len:  368 | eps: 0.050
# Episode 4893 | Return:  415.0 | Len:  415 | eps: 0.050
# Episode 4894 | Return:   59.0 | Len:   59 | eps: 0.050
# Episode 4895 | Return:   17.0 | Len:   17 | eps: 0.050
# Episode 4896 | Return:   80.0 | Len:   80 | eps: 0.050
# Episode 4897 | Return:  133.0 | Len:  133 | eps: 0.050
# Episode 4898 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4899 | Return:  120.0 | Len:  120 | eps: 0.050
# Episode 4900 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4901 | Return:  110.0 | Len:  110 | eps: 0.050
# Episode 4902 | Return:  206.0 | Len:  206 | eps: 0.050
# Episode 4903 | Return:  179.0 | Len:  179 | eps: 0.050
# Episode 4904 | Return:   18.0 | Len:   18 | eps: 0.050
# Episode 4905 | Return:   20.0 | Len:   20 | eps: 0.050
# Episode 4906 | Return:  244.0 | Len:  244 | eps: 0.050
# Episode 4907 | Return:  373.0 | Len:  373 | eps: 0.050
# Episode 4908 | Return:  160.0 | Len:  160 | eps: 0.050
# Episode 4909 | Return:  282.0 | Len:  282 | eps: 0.050
# Episode 4910 | Return:  138.0 | Len:  138 | eps: 0.050
# Episode 4911 | Return:  197.0 | Len:  197 | eps: 0.050
# Episode 4912 | Return:  220.0 | Len:  220 | eps: 0.050
# Episode 4913 | Return:  179.0 | Len:  179 | eps: 0.050
# Episode 4914 | Return:   85.0 | Len:   85 | eps: 0.050
# Episode 4915 | Return:  372.0 | Len:  372 | eps: 0.050
# Episode 4916 | Return:   67.0 | Len:   67 | eps: 0.050
# Episode 4917 | Return:  223.0 | Len:  223 | eps: 0.050
# Episode 4918 | Return:  100.0 | Len:  100 | eps: 0.050
# Episode 4919 | Return:  250.0 | Len:  250 | eps: 0.050
# Episode 4920 | Return:   96.0 | Len:   96 | eps: 0.050
# Episode 4921 | Return:  122.0 | Len:  122 | eps: 0.050
# Episode 4922 | Return:  122.0 | Len:  122 | eps: 0.050
# Episode 4923 | Return:   22.0 | Len:   22 | eps: 0.050
# Episode 4924 | Return:  139.0 | Len:  139 | eps: 0.050
# Episode 4925 | Return:   19.0 | Len:   19 | eps: 0.050
# Episode 4926 | Return:  151.0 | Len:  151 | eps: 0.050
# Episode 4927 | Return:  127.0 | Len:  127 | eps: 0.050
# Episode 4928 | Return:   20.0 | Len:   20 | eps: 0.050
# Episode 4929 | Return:   17.0 | Len:   17 | eps: 0.050
# Episode 4930 | Return:  184.0 | Len:  184 | eps: 0.050
# Episode 4931 | Return:   29.0 | Len:   29 | eps: 0.050
# Episode 4932 | Return:  114.0 | Len:  114 | eps: 0.050
# Episode 4933 | Return:  120.0 | Len:  120 | eps: 0.050
# Episode 4934 | Return:  158.0 | Len:  158 | eps: 0.050
# Episode 4935 | Return:  122.0 | Len:  122 | eps: 0.050
# Episode 4936 | Return:   44.0 | Len:   44 | eps: 0.050
# Episode 4937 | Return:   19.0 | Len:   19 | eps: 0.050
# Episode 4938 | Return:  115.0 | Len:  115 | eps: 0.050
# Episode 4939 | Return:  122.0 | Len:  122 | eps: 0.050
# Episode 4940 | Return:  131.0 | Len:  131 | eps: 0.050
# Episode 4941 | Return:  116.0 | Len:  116 | eps: 0.050
# Episode 4942 | Return:   33.0 | Len:   33 | eps: 0.050
# Episode 4943 | Return:  151.0 | Len:  151 | eps: 0.050
# Episode 4944 | Return:  132.0 | Len:  132 | eps: 0.050
# Episode 4945 | Return:   28.0 | Len:   28 | eps: 0.050
# Episode 4946 | Return:  119.0 | Len:  119 | eps: 0.050
# Episode 4947 | Return:  128.0 | Len:  128 | eps: 0.050
# Episode 4948 | Return:   31.0 | Len:   31 | eps: 0.050
# Episode 4949 | Return:  126.0 | Len:  126 | eps: 0.050
# Episode 4950 | Return:  144.0 | Len:  144 | eps: 0.050
# Episode 4951 | Return:  327.0 | Len:  327 | eps: 0.050
# Episode 4952 | Return:  308.0 | Len:  308 | eps: 0.050
# Episode 4953 | Return:   51.0 | Len:   51 | eps: 0.050
# Episode 4954 | Return:   15.0 | Len:   15 | eps: 0.050
# Episode 4955 | Return:  299.0 | Len:  299 | eps: 0.050
# Episode 4956 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4957 | Return:  401.0 | Len:  401 | eps: 0.050
# Episode 4958 | Return:  462.0 | Len:  462 | eps: 0.050
# Episode 4959 | Return:   33.0 | Len:   33 | eps: 0.050
# Episode 4960 | Return:   13.0 | Len:   13 | eps: 0.050
# Episode 4961 | Return:   19.0 | Len:   19 | eps: 0.050
# Episode 4962 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4963 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4964 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4965 | Return:  472.0 | Len:  472 | eps: 0.050
# Episode 4966 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4967 | Return:  124.0 | Len:  124 | eps: 0.050
# Episode 4968 | Return:  402.0 | Len:  402 | eps: 0.050
# Episode 4969 | Return:  260.0 | Len:  260 | eps: 0.050
# Episode 4970 | Return:  292.0 | Len:  292 | eps: 0.050
# Episode 4971 | Return:   22.0 | Len:   22 | eps: 0.050
# Episode 4972 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4973 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4974 | Return:  286.0 | Len:  286 | eps: 0.050
# Episode 4975 | Return:   37.0 | Len:   37 | eps: 0.050
# Episode 4976 | Return:  480.0 | Len:  480 | eps: 0.050
# Episode 4977 | Return:  399.0 | Len:  399 | eps: 0.050
# Episode 4978 | Return:   15.0 | Len:   15 | eps: 0.050
# Episode 4979 | Return:  310.0 | Len:  310 | eps: 0.050
# Episode 4980 | Return:  273.0 | Len:  273 | eps: 0.050
# Episode 4981 | Return:  500.0 | Len:  500 | eps: 0.050
# Episode 4982 | Return:   35.0 | Len:   35 | eps: 0.050
# Episode 4983 | Return:  332.0 | Len:  332 | eps: 0.050
# Episode 4984 | Return:   73.0 | Len:   73 | eps: 0.050
# Episode 4985 | Return:   59.0 | Len:   59 | eps: 0.050
# Episode 4986 | Return:  200.0 | Len:  200 | eps: 0.050
# Episode 4987 | Return:  210.0 | Len:  210 | eps: 0.050
# Episode 4988 | Return:  149.0 | Len:  149 | eps: 0.050
# Episode 4989 | Return:  175.0 | Len:  175 | eps: 0.050
# Episode 4990 | Return:  462.0 | Len:  462 | eps: 0.050
# Episode 4991 | Return:  185.0 | Len:  185 | eps: 0.050
# Episode 4992 | Return:   17.0 | Len:   17 | eps: 0.050
# Episode 4993 | Return:   16.0 | Len:   16 | eps: 0.050
# Episode 4994 | Return:   16.0 | Len:   16 | eps: 0.050
# Episode 4995 | Return:   27.0 | Len:   27 | eps: 0.050
# Episode 4996 | Return:   76.0 | Len:   76 | eps: 0.050
# Episode 4997 | Return:  153.0 | Len:  153 | eps: 0.050
# Episode 4998 | Return:  123.0 | Len:  123 | eps: 0.050
# Episode 4999 | Return:  119.0 | Len:  119 | eps: 0.050
# Episode 5000 | Return:  111.0 | Len:  111 | eps: 0.050
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (600, 400) to (608, 400) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# ✅ Video saved: cartpole_demo.mp4
